# %%
import scanpy as sc
from scipy import io
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Give the locations of required files and assign your name of interest
# - file_path: Location of the main annData which contains the raw counts
# - gRNA_path: Location of the guide RNA AnnData
# - crispr_index_path: the location of a csv file which has information about gRNA sequences (the file that we used for cumulus is a good example)

# %%
file_path = "/gstore/scratch/u/ghaffars/Dataset/sublib4/raw_qc.h5ad"
Name = 'sublib4'
gRNA_path = "/gstore/scratch/u/ghaffars/Dataset/sublib4/gRNA_qc.h5ad"
crispr_index_path = "/gstore/home/ghaffars/Cumulus/crc_ngs5704/Cumulus/Split_1/cellranger/crispr_index.csv"

# %%
Dataset_HOME = os.path.join('/gstore/scratch/u/ghaffars/scMaGeck', Name)
folderName=os.path.join(Dataset_HOME, f'matrix_files_'+Name)
meta_path = os.path.join(Dataset_HOME, f'metadata_'+Name+'.csv')
barcode_name= os.path.join(Dataset_HOME, f'barcode_rec_'+Name+'.txt')
genes_list = os.path.join(Dataset_HOME, f'all_genes_'+Name+'.csv')

# %% [markdown]
# ## Read the AnnData

# %%
bdata = sc.read(file_path)

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 446413 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase', 'SCN_class'
#     var: 'Symbol'
#     layers: 'counts'

# %%
bdata.obs['gene_symbol'].nunique()
# Out:
# 5117

# %%
bdata.obs['gene_symbol'] = bdata.obs['gene_symbol'].apply(lambda x:x.split('_')[0])

# %%
bdata.obs['gene_symbol'].nunique()
# Out:
# 5117

# %%
bdata.obs['gene_symbol'].value_counts().reset_index()[:10]
# Out:
#      index  gene_symbol
# 0      NTC        11595
# 1   TCF7L2          447
# 2     HBE1          173
# 3  ZNF385D          168
# 4    OVCH1          168
# 5    CLDN7          166
# 6     NAT1          159
# 7  TP53BP2          158
# 8    OR8D2          156
# 9   TVP23B          151

# %%
# !mkdir -p "$folderName"

# %%
with open(folderName + '/barcodes.tsv', 'w') as f:
    for item in bdata.obs_names:
        f.write(item + '\n')
        
with open(folderName + '/features.tsv', 'w') as f:
    for item in ['\t'.join([x,x,'Gene Expression']) for x in bdata.var_names]:
        f.write(item + '\n')
        
io.mmwrite(folderName +'/matrix', bdata.X.T)

bdata.obs.to_csv(meta_path)

# %%
# !ls -p "$folderName"
# Out:
# barcodes.tsv  features.tsv  matrix.mtx

# %%
# !gzip "$folderName"/*

# %%
bdata
# Out:
# AnnData object with n_obs × n_vars = 446413 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase', 'SCN_class'
#     var: 'Symbol'
#     layers: 'counts'

# %% [markdown]
# ## Generate gRNA count matrix

# %%
gdata = sc.read(gRNA_path)

# %%
gdata
# Out:
# AnnData object with n_obs × n_vars = 446413 × 20872
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'qc_pass'
#     layers: 'counts'

# %%
gdata.obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGGAATCGC   SAM24443678  AAACCCAAGGAATCGC
# SAM24443678_rep1-AAACCCAAGTCTTCCC   SAM24443678  AAACCCAAGTCTTCCC
# SAM24443678_rep1-AAACCCACACAGCTGC   SAM24443678  AAACCCACACAGCTGC
# SAM24443678_rep1-AAACCCACATGAATAG   SAM24443678  AAACCCACATGAATAG
# SAM24443678_rep1-AAACCCATCGACCATA   SAM24443678  AAACCCATCGACCATA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGCACCTGCGA  SAM24449114  TTTGTTGCACCTGCGA
# SAM24449114_rep12-TTTGTTGCATTGCTTT  SAM24449114  TTTGTTGCATTGCTTT
# SAM24449114_rep12-TTTGTTGGTATGGGAC  SAM24449114  TTTGTTGGTATGGGAC
# SAM24449114_rep12-TTTGTTGGTATTTCTC  SAM24449114  TTTGTTGGTATTTCTC
# SAM24449114_rep12-TTTGTTGTCCGTGGCA  SAM24449114  TTTGTTGTCCGTGGCA
#
#                                    DemuxType_crispr DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGGAATCGC           singlet      ENSG00000135093_3
# SAM24443678_rep1-AAACCCAAGTCTTCCC           singlet      ENSG00000181915_1
# SAM24443678_rep1-AAACCCACACAGCTGC           singlet      ENSG00000288711_4
# SAM24443678_rep1-AAACCCACATGAATAG           singlet      ENSG00000103365_2
# SAM24443678_rep1-AAACCCATCGACCATA           singlet      ENSG00000139190_2
# ...                                             ...                    ...
# SAM24449114_rep12-TTTGTTGCACCTGCGA          singlet      ENSG00000189068_2
# SAM24449114_rep12-TTTGTTGCATTGCTTT          singlet      ENSG00000278646_1
# SAM24449114_rep12-TTTGTTGGTATGGGAC          singlet      ENSG00000110723_2
# SAM24449114_rep12-TTTGTTGGTATTTCTC          singlet      ENSG00000167840_3
# SAM24449114_rep12-TTTGTTGTCCGTGGCA          singlet      ENSG00000170421_2
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGGAATCGC            singlet             SAM24439045
# SAM24443678_rep1-AAACCCAAGTCTTCCC            singlet             SAM24439044
# SAM24443678_rep1-AAACCCACACAGCTGC            singlet             SAM24439044
# SAM24443678_rep1-AAACCCACATGAATAG            singlet             SAM24439045
# SAM24443678_rep1-AAACCCATCGACCATA            singlet             SAM24439045
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGCACCTGCGA           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGCATTGCTTT           singlet             SAM24439043
# SAM24449114_rep12-TTTGTTGTCCGTGGCA  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
#
#                                    gRNA_library_MOI      gene_symbol   class  \
# SAM24443678_rep1-AAACCCAAGGAATCGC               0.4            USP30  target
# SAM24443678_rep1-AAACCCAAGTCTTCCC               0.4              ADO  target
# SAM24443678_rep1-AAACCCACACAGCTGC               0.4  ENSG00000288711  target
# SAM24443678_rep1-AAACCCACATGAATAG               0.4             GGA2  target
# SAM24443678_rep1-AAACCCATCGACCATA               0.4            VAMP1  target
# ...                                             ...              ...     ...
# SAM24449114_rep12-TTTGTTGCACCTGCGA              0.4            VSTM1  target
# SAM24449114_rep12-TTTGTTGCATTGCTTT              0.4  ENSG00000278646  target
# SAM24449114_rep12-TTTGTTGGTATGGGAC              0.4            EXPH5  target
# SAM24449114_rep12-TTTGTTGGTATTTCTC              0.4           ZNF232  target
# SAM24449114_rep12-TTTGTTGTCCGTGGCA              0.4             KRT8  target
#
#                                     qc_pass
# SAM24443678_rep1-AAACCCAAGGAATCGC      True
# SAM24443678_rep1-AAACCCAAGTCTTCCC      True
# SAM24443678_rep1-AAACCCACACAGCTGC      True
# SAM24443678_rep1-AAACCCACATGAATAG      True
# SAM24443678_rep1-AAACCCATCGACCATA      True
# ...                                     ...
# SAM24449114_rep12-TTTGTTGCACCTGCGA     True
# SAM24449114_rep12-TTTGTTGCATTGCTTT     True
# SAM24449114_rep12-TTTGTTGGTATGGGAC     True
# SAM24449114_rep12-TTTGTTGGTATTTCTC     True
# SAM24449114_rep12-TTTGTTGTCCGTGGCA     True
#
# [446413 rows x 17 columns]

# %%
COL = gdata.obs.columns.to_list()

# %%
tmp = gdata.obs.drop(columns=COL)

# %%
df = bdata.obs.join(tmp)

# %%
df
# Out:
#                                          Sample           Barcode  \
# SAM24449114_rep1-AAACCCAAGACTGTTC   SAM24449114  AAACCCAAGACTGTTC
# SAM24449114_rep1-AAACCCAAGAGAACCC   SAM24449114  AAACCCAAGAGAACCC
# SAM24449114_rep1-AAACCCAAGATGCGAC   SAM24449114  AAACCCAAGATGCGAC
# SAM24449114_rep1-AAACCCAAGCCTATCA   SAM24449114  AAACCCAAGCCTATCA
# SAM24449114_rep1-AAACCCAAGCGCTTCG   SAM24449114  AAACCCAAGCGCTTCG
# ...                                         ...               ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC  SAM24443678  TTTGTTGGTATGAGGC
# SAM24443678_rep24-TTTGTTGGTTTACGTG  SAM24443678  TTTGTTGGTTTACGTG
# SAM24443678_rep24-TTTGTTGTCAGACCCG  SAM24443678  TTTGTTGTCAGACCCG
# SAM24443678_rep24-TTTGTTGTCCTTATAC  SAM24443678  TTTGTTGTCCTTATAC
# SAM24443678_rep24-TTTGTTGTCGTTCGCT  SAM24443678  TTTGTTGTCGTTCGCT
#
#                                    DemuxType_crispr DemuxAssignment_crispr  \
# SAM24449114_rep1-AAACCCAAGACTGTTC           singlet      ENSG00000138767_2
# SAM24449114_rep1-AAACCCAAGAGAACCC           singlet      ENSG00000081386_1
# SAM24443678_rep24-TTTGTTGGTTTACGTG         8771             126      1.436552
# SAM24443678_rep24-TTTGTTGTCAGACCCG         8692             333      3.831109
# SAM24443678_rep24-TTTGTTGTCCTTATAC         8220             468      5.693431
# SAM24443678_rep24-TTTGTTGTCGTTCGCT         5643             411      7.283360
#
#                                    total_counts_ribo pct_counts_ribo qc_pass  \
# SAM24449114_rep1-AAACCCAAGACTGTTC               2172       18.456832    True
# SAM24449114_rep1-AAACCCAAGAGAACCC               1212       26.619811    True
# SAM24449114_rep1-AAACCCAAGATGCGAC               2143       23.407974    True
# SAM24449114_rep1-AAACCCAAGCCTATCA               1990       21.044839    True
# SAM24449114_rep1-AAACCCAAGCGCTTCG               1714       18.162552    True
# ...                                              ...             ...     ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC               993       18.337950    True
# SAM24443678_rep24-TTTGTTGGTTTACGTG              1507       17.181621    True
# SAM24443678_rep24-TTTGTTGTCAGACCCG              1544       17.763461    True
# SAM24443678_rep24-TTTGTTGTCCTTATAC              1311       15.948905    True
# SAM24443678_rep24-TTTGTTGTCGTTCGCT               921       16.321106    True
#
#                                      S_score  G2M_score  phase  \
# SAM24449114_rep1-AAACCCAAGACTGTTC  -1.879157  -1.713006     G1
# SAM24449114_rep1-AAACCCAAGAGAACCC  -0.465551  -0.736520     G1
# SAM24449114_rep1-AAACCCAAGATGCGAC  -0.290915  -0.803445     G1
# SAM24449114_rep1-AAACCCAAGCCTATCA  -0.524886  -0.383549     G1
# SAM24449114_rep1-AAACCCAAGCGCTTCG   0.119865  -0.565891      S
# ...                                      ...        ...    ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC -0.594545  -0.008441     G1
# SAM24443678_rep24-TTTGTTGGTTTACGTG -0.381656   1.300689    G2M
# SAM24443678_rep24-TTTGTTGTCAGACCCG  0.138666  -0.371232      S
# SAM24443678_rep24-TTTGTTGTCCTTATAC -0.163334  -0.185702     G1
# SAM24443678_rep24-TTTGTTGTCGTTCGCT -0.105303   0.186822    G2M
#
#                                              SCN_class
# SAM24449114_rep1-AAACCCAAGACTGTTC   Untreatedclus_DLD1
# SAM24449114_rep1-AAACCCAAGAGAACCC   Untreatedclus_DLD1
# SAM24449114_rep1-AAACCCAAGATGCGAC   Untreatedclus_DLD1
# SAM24449114_rep1-AAACCCAAGCCTATCA   Untreatedclus_DLD1
# SAM24449114_rep1-AAACCCAAGCGCTTCG   Untreatedclus_DLD1
# ...                                                ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC  Untreatedclus_DLD1
# SAM24443678_rep24-TTTGTTGGTTTACGTG  Untreatedclus_DLD1
# SAM24443678_rep24-TTTGTTGTCAGACCCG  Untreatedclus_DLD1
# SAM24443678_rep24-TTTGTTGTCCTTATAC  Untreatedclus_DLD1
# SAM24443678_rep24-TTTGTTGTCGTTCGCT  Untreatedclus_DLD1
#
# [446413 rows x 27 columns]

# %%
gdata.obs = df.copy()

# %%
gdata.obs['DemuxAssignment_crispr']=gdata.obs['DemuxAssignment_crispr'].apply(lambda x:x.split(',')[0])

# %%
gdata.obs[gdata.obs['DemuxAssignment_crispr'].str.contains(',')]
# Out:
# Empty DataFrame
# Columns: [Sample, Barcode, DemuxType_crispr, DemuxAssignment_crispr, DemuxType_hashing, DemuxAssignment_hashing, cellline, timepoint, HTO, NGS_ID, Biological_replicate, 10Xrun, sublibrary, gRNA_library_MOI, gene_symbol, class, n_genes_by_counts, total_counts, total_counts_mt, pct_counts_mt, total_counts_ribo, pct_counts_ribo, qc_pass, S_score, G2M_score, phase, SCN_class]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ## Read sgRNA info from crispr_index

# %%
sgRNA = pd.read_csv(crispr_index_path,header=None)

# %%
sgRNA.columns= ['sgseq','DemuxAssignment_crispr','crispr']

# %%
sgRNA = sgRNA[['sgseq','DemuxAssignment_crispr']]

# %%
sgRNA
# Out:
#                      sgseq DemuxAssignment_crispr
# 0      ATAGTAAGGTGCAGAGCGC      ENSG00000000457_1
# 1      ACTGAGCGAGTACAGCCCC      ENSG00000000457_2
# 2      ATCCCGCTGTACTGCAAGA      ENSG00000000457_3
# 3      CTTGTACTGTGGAAGCGGA      ENSG00000000457_4
# 4      TGGTGTGCTTTAGAAATCC      ENSG00000000460_1
# ...                    ...                    ...
# 20867  CGTATTATCGCCGGTGGTT               NTC_2013
# 20868  GTCGGTCGCTCGATCGTAA               NTC_2014
# 20869  CGCCGTACGTACGCCGGAT               NTC_2015
# 20870  GCGCGCCCGGATACTATAC               NTC_2016
# 20871  CGAAGCATAACCGCGATCG               NTC_2017
#
# [20872 rows x 2 columns]

# %%
DF = gdata.obs.reset_index().merge(sgRNA, how='left', on='DemuxAssignment_crispr').set_index('index')

# %%
DF
# Out:
#                                          Sample           Barcode  \
# index
# SAM24449114_rep1-AAACCCAAGACTGTTC   SAM24449114  AAACCCAAGACTGTTC
# SAM24449114_rep1-AAACCCAAGAGAACCC   SAM24449114  AAACCCAAGAGAACCC
# SAM24449114_rep1-AAACCCAAGATGCGAC   SAM24449114  AAACCCAAGATGCGAC
# SAM24449114_rep1-AAACCCAAGCCTATCA   SAM24449114  AAACCCAAGCCTATCA
# SAM24449114_rep1-AAACCCAAGCGCTTCG   SAM24449114  AAACCCAAGCGCTTCG
# ...                                         ...               ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC  SAM24443678  TTTGTTGGTATGAGGC
# SAM24443678_rep24-TTTGTTGGTTTACGTG  SAM24443678  TTTGTTGGTTTACGTG
# SAM24443678_rep24-TTTGTTGTCAGACCCG  SAM24443678  TTTGTTGTCAGACCCG
# SAM24443678_rep24-TTTGTTGTCCTTATAC  SAM24443678  TTTGTTGTCCTTATAC
# SAM24443678_rep24-TTTGTTGTCGTTCGCT  SAM24443678  TTTGTTGTCGTTCGCT
#
#                                    DemuxType_crispr DemuxAssignment_crispr  \
# index
# SAM24449114_rep1-AAACCCAAGACTGTTC           singlet      ENSG00000138767_2
# SAM24449114_rep1-AAACCCAAGAGAACCC           singlet      ENSG00000081386_1
# SAM24449114_rep1-AAACCCAAGATGCGAC           singlet      ENSG00000180228_3
# SAM24449114_rep1-AAACCCAAGCCTATCA           singlet               NTC_1819
# SAM24449114_rep1-AAACCCAAGCGCTTCG           singlet      ENSG00000198933_4
# ...                                             ...                    ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC          singlet      ENSG00000185024_4
# SAM24443678_rep24-TTTGTTGGTTTACGTG          singlet      ENSG00000073282_4
# SAM24443678_rep24-TTTGTTGTCAGACCCG          singlet      ENSG00000169946_1
# SAM24443678_rep24-TTTGTTGTCCTTATAC          singlet      ENSG00000089775_3
# SAM24443678_rep24-TTTGTTGTCGTTCGCT          singlet      ENSG00000101017_2
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# index
# SAM24449114_rep1-AAACCCAAGACTGTTC            singlet             SAM24439044
# SAM24449114_rep1-AAACCCAAGAGAACCC            singlet             SAM24439044
# SAM24449114_rep1-AAACCCAAGATGCGAC            singlet             SAM24439045
# SAM24449114_rep1-AAACCCAAGCCTATCA            singlet             SAM24439043
# SAM24449114_rep1-AAACCCAAGCGCTTCG            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC           singlet             SAM24439045
# SAM24443678_rep24-TTTGTTGGTTTACGTG           singlet             SAM24439044
# SAM24443678_rep24-TTTGTTGTCAGACCCG           singlet             SAM24439044
# SAM24443678_rep24-TTTGTTGTCCTTATAC           singlet             SAM24439043
# SAM24443678_rep24-TTTGTTGTCGTTCGCT           singlet             SAM24439043
#
#                                    cellline timepoint     HTO   NGS_ID  ...  \
# index                                                                   ...
# SAM24449114_rep1-AAACCCAAGACTGTTC      DLD1      day5  HTO-14  NGS5704  ...
# SAM24449114_rep1-AAACCCAAGAGAACCC      DLD1      day5   HTO-6  NGS5704  ...
# SAM24449114_rep1-AAACCCAAGATGCGAC      DLD1      day5   HTO-7  NGS5704  ...
# SAM24449114_rep1-AAACCCAAGCCTATCA      DLD1      day5   HTO-2  NGS5704  ...
# SAM24449114_rep1-AAACCCAAGCGCTTCG      DLD1      day5  HTO-11  NGS5704  ...
# ...                                     ...       ...     ...      ...  ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC     DLD1      day5   HTO-8  NGS5570  ...
# SAM24443678_rep24-TTTGTTGGTTTACGTG     DLD1      day5  HTO-15  NGS5570  ...
# SAM24443678_rep24-TTTGTTGTCAGACCCG     DLD1      day5  HTO-15  NGS5570  ...
# SAM24443678_rep24-TTTGTTGTCCTTATAC     DLD1      day5  HTO-10  NGS5570  ...
# SAM24443678_rep24-TTTGTTGTCGTTCGCT     DLD1      day5  HTO-12  NGS5570  ...
#
#                                    total_counts_mt pct_counts_mt  \
# index
# SAM24449114_rep1-AAACCCAAGACTGTTC              193      1.640041
# SAM24449114_rep1-AAACCCAAGAGAACCC               50      1.098177
# SAM24449114_rep1-AAACCCAAGATGCGAC              314      3.429820
# SAM24449114_rep1-AAACCCAAGCCTATCA              324      3.426396
# SAM24449114_rep1-AAACCCAAGCGCTTCG              474      5.022783
# ...                                            ...           ...
# SAM24443678_rep24-TTTGTTGGTATGAGGC             305      5.632502
# SAM24443678_rep24-TTTGTTGGTTTACGTG             126      1.436552
# SAM24443678_rep24-TTTGTTGTCAGACCCG             333      3.831109
with open(barcode_name, 'w') as f:
    print('cell\tbarcode\tsgrna\tgene\tread_count\tumi_count',file=f)
    for i in range(gdata.X.shape[0]):
        
        cell_bc = DF.index[i]
        sg = DF['DemuxAssignment_crispr'].iloc[i]
        sgseq = DF['sgseq'].iloc[i]
        geneid  = DF['gene_symbol'].iloc[i]
        j = gdata.var.index.get_loc(gdata.var.index[gdata.var.index==DF['DemuxAssignment_crispr'].iloc[i]][0])
        umi_count = gdata.X[i,j]
        
        
        print('\t'.join([cell_bc,sg,sgseq,geneid,str(rcount),str(umi_count)]),file=f)

# %%
BARCODE_REC= pd.read_csv(barcode_name, delimiter='\t')

# %%
BARCODE_REC['gene'].nunique()
# Out:
# 5117

# %%
BARCODE_REC
# Out:
#                                       cell            barcode  \
# 0        SAM24449114_rep1-AAACCCAAGACTGTTC  ENSG00000138767_2
# 1        SAM24449114_rep1-AAACCCAAGAGAACCC  ENSG00000081386_1
# 2        SAM24449114_rep1-AAACCCAAGATGCGAC  ENSG00000180228_3
# 3        SAM24449114_rep1-AAACCCAAGCCTATCA           NTC_1819
# 4        SAM24449114_rep1-AAACCCAAGCGCTTCG  ENSG00000198933_4
# ...                                    ...                ...
# 446408  SAM24443678_rep24-TTTGTTGGTATGAGGC  ENSG00000185024_4
# 446409  SAM24443678_rep24-TTTGTTGGTTTACGTG  ENSG00000073282_4
# 446410  SAM24443678_rep24-TTTGTTGTCAGACCCG  ENSG00000169946_1
# 446411  SAM24443678_rep24-TTTGTTGTCCTTATAC  ENSG00000089775_3
# 446412  SAM24443678_rep24-TTTGTTGTCGTTCGCT  ENSG00000101017_2
#
#                       sgrna    gene  read_count  umi_count
# 0       GAGCCTAAGTACATCACTT  CNOT6L           0          0
# 1       AACTCTGTGAACCGACGTC  ZNF510           0          0
# 2       CCTGGGAAAGGGTATATTC   PRKRA           0          0
# 3       TCTCGCGCTTACGTTGCGA     NTC           0          0
# 4       TCCCGGAGACCCCTCGCTT  TBKBP1           0          0
# ...                     ...     ...         ...        ...
# 446408  AGCCAGAATGCATGACTTC    BRF1           0          0
# 446409  CGAATCAAATGACTAGGAG    TP63           0          0
# 446410  AAGTTTGCCGCTAGGGACA   ZFPM2           0          0
# 446411  ATAGCTGAATATGTCAGGT  ZBTB25           0          0
# 446412  AAACGGAATGCCTTCCTTG    CD40           0          0
#
# [446413 rows x 6 columns]

# %%
GENES = BARCODE_REC.drop_duplicates(['gene']).reset_index(drop=True)

# %%
GENES
# Out:
#                                     cell            barcode  \
# 0      SAM24449114_rep1-AAACCCAAGACTGTTC  ENSG00000138767_2
# 1      SAM24449114_rep1-AAACCCAAGAGAACCC  ENSG00000081386_1
# 2      SAM24449114_rep1-AAACCCAAGATGCGAC  ENSG00000180228_3
# 3      SAM24449114_rep1-AAACCCAAGCCTATCA           NTC_1819
# 4      SAM24449114_rep1-AAACCCAAGCGCTTCG  ENSG00000198933_4
# ...                                  ...                ...
# 5112  SAM24449114_rep10-AACGAAAGTTGCCTAA  ENSG00000103035_3
# 5113  SAM24449114_rep10-AGCTTCCAGGGCATGT  ENSG00000181222_1
# 5114  SAM24449114_rep10-CACGTTCTCCAGCAAT  ENSG00000154473_4
# 5115  SAM24449114_rep12-ACGATGTGTCCGAAGA  ENSG00000249209_3
# 5116   SAM24443678_rep1-TACTTCAGTCATCTAG  ENSG00000170312_4
#
#                     sgrna             gene  read_count  umi_count
# 0     GAGCCTAAGTACATCACTT           CNOT6L           0          0
# 1     AACTCTGTGAACCGACGTC           ZNF510           0          0
# 2     CCTGGGAAAGGGTATATTC            PRKRA           0          0
# 3     TCTCGCGCTTACGTTGCGA              NTC           0          0
# 4     TCCCGGAGACCCCTCGCTT           TBKBP1           0          0
# ...                   ...              ...         ...        ...
# 5112  CACACTGAGCAGCACCAGG            PSMD7           0          0
# 5113  TGGTCGTGTCCGGAGCTAA           POLR2A           0          0
# 5114  CTCCACTCCAGGCATGCGT             BUB3           0          0
# 5115  GCTCTGCTGGAAGGTACAA  ENSG00000249209           0          0
# 5116  ATCCATGTACTGACCAGGA             CDK1           0          0
#
# [5117 rows x 6 columns]

# %%
GENES.to_csv(genes_list, index=False)

# %% [markdown]
# ### Optional: List of genes from energy Distance to process

# %%
ED = pd.read_csv("/gstore/project/crc_recursion_2/Sublib2_normcontrol/DS000015963/Energy_Distance/aggregated_energy_distace.csv")

# %%
GENES_list = ED[ED['phenotype_@0.05']=='Yes']['gene_symbol'].unique().tolist()

# %%
len(GENES_list)
# Out:
# 1272

# %%
GENES = ED[ED['phenotype_@0.05']=='Yes'].drop_duplicates(['gene_symbol']).reset_index(drop=True)

# %%
GENES
# Out:
#      gene_symbol                   key  energy_distance_pvalue  \
# 0          RPLP2   perGene_pca_sphered                   0.001
# 1         FER1L5  perGene_pca_centered                   0.001
# 2            YY1   perGene_pca_sphered                   0.001
# 3           LSM3   perGene_pca_sphered                   0.001
# 4          PRPF4  perGene_pca_centered                   0.001
# ...          ...                   ...                     ...
# 1267      DHCR24   perGene_pca_sphered                   0.050
# 1268       EPCAM   perGene_pca_sphered                   0.050
# 1269      ADGRG5   perGene_pca_sphered                   0.050
# 1270    ANKRD18B   perGene_pca_sphered                   0.050
# 1271        MDH2   perGene_pca_sphered                   0.050
#
#       energy_distance_statistic phenotype_@0.05  cell_counts_per_gene  \
# 0                      0.231738             Yes                  52.0
# 1                      0.399202             Yes                 100.0
# 2                      0.176572             Yes                 118.0
# 3                      0.191618             Yes                  90.0
# 4                      1.475709             Yes                  43.0
# ...                         ...             ...                   ...
# 1267                   0.066310             Yes                 108.0
# 1268                   0.059743             Yes                 119.0
# 1269                   0.053979             Yes                 139.0
# 1270                   0.065793             Yes                 106.0
# 1271                   0.058993             Yes                 127.0
#
#       -log10pval  log10stat  iteration
# 0        3.00000  -0.635002       10.0
# 1        3.00000  -0.398807        5.0
# 2        3.00000  -0.753078        9.0
# 3        3.00000  -0.717565       10.0
# 4        3.00000   0.169001        6.0
# ...          ...        ...        ...
# 1267     1.30103  -1.178421        1.0
# 1268     1.30103  -1.223715        5.0
# 1269     1.30103  -1.267771        3.0
# 1270     1.30103  -1.181819       10.0
# 1271     1.30103  -1.229201        1.0
#
# [1272 rows x 9 columns]

# %%
GENES.to_csv("genes_list_from_ED.csv", index=False)
